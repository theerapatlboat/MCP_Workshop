# %% [markdown]
# # Prompting

# %%
from rich import print

# %%
from openai import OpenAI # เรียกใช้งาน OpenAI Library
API_KEY="REDACTED_OPENAI_API_KEY" # ใช้งาน GPT-5 หรือ GPT ตัวอื่น ๆ
client = OpenAI(
    api_key = API_KEY,
)
base_model = "gpt-5.2"

# %% [markdown]
# ## Variable

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            a = 123
            b = 321
            a + b = ?
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# a = 123, b = 321
#
# a + b = 123 + 321 = **444**

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            a = 123
            b = 321
            c = Hello
            d = World
            c + d = ?
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# If `c = Hello` and `d = World`, then concatenating them:
#
# - `c + d = HelloWorld`
#
# (If you intend a space between them, it would be `Hello World`.)

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            <a> 123456 </a>
            <b> Hello world </b>

            Chang <a> into spelling words
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# If you want to change the number inside `<a>` from `123456` into spelling words, you can do it with JavaScript by
# reading the text, converting it, then writing it back.
#
# ### Example (HTML + JS)
#
# ```html
# <a id="num">123456</a>
# <b>Hello world</b>
#
# <script>
#   function numberToWords(n) {
#     const ones = ["","one","two","three","four","five","six","seven","eight","nine"];
#     const teens =
# ["ten","eleven","twelve","thirteen","fourteen","fifteen","sixteen","seventeen","eighteen","nineteen"];
#     const tens = ["","","twenty","thirty","forty","fifty","sixty","seventy","eighty","ninety"];
#
#     function toWords(num) {
#       if (num === 0) return "";
#       if (num < 10) return ones;
#       if (num < 20) return teens;
#       if (num < 100) return tens[Math.floor(num / 10)] + (num % 10 ? " " + ones : "");
#       if (num < 1000) return ones[Math.floor(num / 100)] + " hundred" + (num % 100 ? " " + toWords(num % 100) :
# "");
# ...

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            {
              "a" : 123456789
              "b" : "bob"
            }

            What is b ?
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# In that JSON object, **`b` is the string `"bob"`**.

# %% [markdown]
# ## Condition

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            word list => [Hello, Sandwich, Food, Bob]

            if word list is type of food change into Food.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# If you have a list like:
#
# ```text
# [Hello, Sandwich, Food, Bob]
# ```
#
# and you want: “if a word is a type of food, replace it with `Food`”, you can do it like this (example in Python):
#
# ```python
# words = ["Hello", "Sandwich", "Food", "Bob"]
#
# food_words = {"Sandwich", "Pizza", "Burger", "Apple"}  # your food vocabulary
#
# result = ["Food" if w in food_words else w for w in words]
# print(result)  # ['Hello', 'Food', 'Food', 'Bob']
# ```
#
# Notes:
# - If you want `"Food"` itself to stay `"Food"`, include it in `food_words` (as above) or treat it separately.
# - If you instead mean “replace any word that *contains* a food word” or needs NLP categorization, tell me your
# language/tooling and how you define “type of food”.

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            word list => [Sad, Angry, Happy, Kudos]

            Change word list into colors.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# Here are common color associations for those words (with hex codes you can use):
#
# - **Sad** → **Blue** `#1E90FF`
# - **Angry** → **Red** `#FF0000`
# - **Happy** → **Yellow** `#FFD700`
# - **Kudos** → **Green** `#2ECC71`
#
# If you tell me your context (UI theme, chart, badges), I can adjust the shades to match your design.

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            word list => [Sad, Angry, Happy, Kudos]

            Change word list into colors. And group into similar.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# Here’s one clear way to map your words to colors and group similar ones by “valence” (negative vs positive):
#
# ## Negative (cool/dark tones)
# - **Sad** → **Blue** (e.g., `#3B82F6`)
# - **Angry** → **Red** (e.g., `#EF4444`)
#
# ## Positive (warm/bright tones)
# - **Happy** → **Yellow** (e.g., `#FACC15`)
# - **Kudos** → **Green** (e.g., `#22C55E`)
#
# If you want them grouped by **arousal/energy** instead (calm vs high-energy), say so and I’ll regroup accordingly.

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            word list => [Sad, Angry, Happy, Kudos]

            Get words in word list only positive emotion.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# From the list **[Sad, Angry, Happy, Kudos]**, the **positive emotion** words are:
#
# - **Happy**
# - **Kudos**

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            <Email> Hello Nathan,
            How about you guy ?
            Hope you get well soon.
            Best
            Bob.
            <Email>

            Remove name in <Email> and replace with placeholder.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# <Email> Hello [NAME],
# How about you guy ?
# Hope you get well soon.
# Best
# [NAME].
# <Email>

# %% [markdown]
# ## Demonstration

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            สวัสดี -> Hello
            ข้าว -> Rice
            อาคาร -> Building
            อาหารเช้า ->
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# อาหารเช้า -> Breakfast

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            Rice -> Noun
            Eat -> Verb
            Sleep -> Verb
            Food ->
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# Rice -> Noun
# Eat -> Verb
# Sleep -> Verb
# Food -> Noun

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
a = Hello
b = World
c = Float16
d = 888 -> Hello World Float16

a = Ciao
b = 7255
c = Float16
d = 866293 -> Ciao Float16

a = ><
b = -><-
c = Float16
d = Hi -> Float16 Hi

a = Float16
b = 11
c = Hey
d = 222 ->
"""
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# From the examples, **`d` is a “template string” built by scanning the value of `d` left→right and substituting
# certain digit tokens with `a`, `b`, `c`**, while leaving any other characters (spaces, arrows, words) as-is.
#
# The digit-to-variable mapping that fits all given lines is:
#
# - **`8` → `a`**
# - **`7` → `b`**
# - **`9` → `c`**
# - Any other digits (e.g., `0–6`) are **ignored/removed** from the output.
#
# Check against your examples:
#
# 1) `d = 888`
# `8 8 8` → `a a a` → with `a=Hello`, but the shown result is `Hello World Float16`.
# This indicates **consecutive substitutions are collapsed to one each in the order a,b,c when present** in that `d`:
# - `888` contains only token `8` ⇒ include `a`
# - but output includes `b` and `c` too, so it’s instead consistent with:
#   - **presence of `8` includes `a`**
#   - **presence of `7` includes `b`**
#   - **presence of `9` includes `c`**
# ...

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
Yanik is a 56-year-old male. -> {
 "name" : "Yanik",
 "age" : "56",
 "gender" : "male"
}

Martha is a 62-year-old female. -> {
 "name" : "Martha",
 "age" : "62",
 "gender" : "female"
}

Carlos is a 45-year-old male. -> {
 "name" : "Carlos",
 "age" : "45",
 "gender" : "male"
}


===================================================

Linda is a 50-year-old female. ->
"""
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ```json
# {
#   "name": "Linda",
#   "age": "50",
#   "gender": "female"
# }
# ```

# %% [markdown]
# ## Loop

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            food list = []

            Add food name into food list 10 times.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ```python
# food_list = []
#
# for _ in range(10):
#     food_name = input("Enter a food name: ")
#     food_list.append(food_name)
#
# print(food_list)
# ```

# %%
from openai import OpenAI # เรียกใช้งาน OpenAI Library
API_KEY="REDACTED_OPENAI_API_KEY" # ใช้งาน GPT-5 หรือ GPT ตัวอื่น ๆ
client = OpenAI(
    api_key = API_KEY,
)
base_model = "gpt-5.2"

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            DON'T REPLY CODE

            food list = []
            Add food name into food list 10 times.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# I can’t provide code.
#
# To do this without code: write down the food name and add it to the list repeatedly until it appears 10 times
# (i.e., the list contains 10 entries of the same food name).

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            food list

            1. Add difference food name into food list 10 times.
            2. Show every food name when added into food list.
            3. If food is red replace with RED
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ```python
# # food list
#
# foods = []
# red_foods = {"apple", "strawberry", "cherry", "tomato", "watermelon", "raspberry", "pomegranate", "red pepper"}
#
# for i in range(10):
#     name = input(f"Enter food #{i+1}: ").strip()
#
#     # 3) If food is red replace with RED
#     if name.lower() in red_foods:
#         name = "RED"
#
#     # 1) Add different food names only
#     if name in foods:
#         print("Already in the list, enter a different food.")
#         continue
#
#     foods.append(name)
#
#     # 2) Show every food name when added
#     print("Current food list:")
#     for f in foods:
#         print(f"- {f}")
# ```
#
# If you want it to *force exactly 10 unique items* (i.e., keep asking until the list has 10), tell me what language
# you’re using (Python/Java/C/etc.) and I’ll adjust it.

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            food list

            1. Add difference food name into food list.
            2. Show every food name when added into food list.
            3. If food is red replace with RED
            4. If RED more than 2. Stop.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# Food List:
# 1. Apple
# 2. Banana
# 3. Tomato
# 4. Strawberry
# 5. Grape
# 6. Watermelon
#
# Show every food name when added into food list:
# - Apple added to food list.
# - Banana added to food list.
# - Tomato added to food list.
# - Strawberry added to food list.
# - Grape added to food list.
# - Watermelon added to food list.
#
# After replacing "Tomato" with "RED":
# - Apple added to food list.
# - Banana added to food list.
# - RED added to food list.
# - Strawberry added to food list.
# - Grape added to food list.
# - Watermelon added to food list.
#
# After replacing "Strawberry" with "RED":
# - Apple added to food list.
# - Banana added to food list.
# - RED added to food list.
# - RED added to food list.
# - Grape added to food list.
# - Watermelon added to food list.
#
# Since "RED" appears more than twice, the process stops at this point.

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            1. Start with the number value 1.
            2. Show the number value.
            3. Increment the number by 1.
            4. If the number exceeds 5, stop.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# 1. 1
# 2. 1
# 3. 2
# 4. 3
# 5. 4
# 6. 5

# %% [markdown]
# ## Formating

# %%
from openai import OpenAI # เรียกใช้งาน OpenAI Library
API_KEY="REDACTED_OPENAI_API_KEY" # ใช้งาน GPT-5 หรือ GPT ตัวอื่น ๆ
client = OpenAI(
    api_key = API_KEY,
)
base_model = "gpt-5.2"

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            ID,Name,Email,Age,Country
            1,John Doe,john.doe@example.com,28,United States
            2,Jane Smith,jane.smith@example.com,34,Canada
            3,Michael Brown,michael.brown@example.com,45,United Kingdom
            4,Emily Davis,emily.davis@example.com,22,Australia
            5,David Wilson,david.wilson@example.com,30,New Zealand

            Convert into json format.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "ID": 1,
#     "Name": "John Doe",
#     "Email": "john.doe@example.com",
#     "Age": 28,
#     "Country": "United States"
#   },
#   {
#     "ID": 2,
#     "Name": "Jane Smith",
#     "Email": "jane.smith@example.com",
#     "Age": 34,
#     "Country": "Canada"
#   },
#   {
#     "ID": 3,
#     "Name": "Michael Brown",
#     "Email": "michael.brown@example.com",
#     "Age": 45,
#     "Country": "United Kingdom"
#   },
#   {
#     "ID": 4,
#     "Name": "Emily Davis",
#     "Email": "emily.davis@example.com",
#     "Age": 22,
#     "Country": "Australia"
#   },
#   {
#     "ID": 5,
#     "Name": "David Wilson",
#     "Email": "david.wilson@example.com",
#     "Age": 30,
#     "Country": "New Zealand"
#   }
# ]
# ```

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            [
              {
                "user_id": 1,
                "name": "Alice Johnson",
                "email": "alice.johnson@example.com",
                "password": "P@ssw0rd123"
              },
              {
                "user_id": 2,
                "name": "Bob Smith",
                "email": "bob.smith@example.com",
                "password": "SecurePass456"
              },
              {
                "user_id": 3,
                "name": "Charlie Brown",
                "email": "charlie.brown@example.com",
                "password": "MyP@ssw0rd789"
              },
              {
                "user_id": 4,
                "name": "Diana Prince",
                "email": "diana.prince@example.com",
                "password": "WonderW0man!"
              },
              {
                "user_id": 5,
                "name": "Ethan Hunt",
                "email": "ethan.hunt@example.com",
                "password": "M1ssionImp0ssible"
              }
            ]


            Convert into test case report.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ## Test Case Report — User Data Validation
#
# **Test Suite:** User Registration/Login Test Data
# **Test Data Source:** Provided JSON array (5 user records)
# **Objective:** Verify each user record contains valid and complete fields: `user_id`, `name`, `email`, `password`.
#
# ### Assumptions / Validation Rules
# - `user_id`: required, integer, unique, > 0
# - `name`: required, non-empty string
# - `email`: required, valid email format, unique
# - `password`: required, non-empty string (complexity not enforced unless specified)
#
# ---
#
# ### Execution Summary
# | Total Records | Passed | Failed |
# |---:|---:|---:|
# | 5 | 5 | 0 |
#
# ---
#
# ### Detailed Test Cases
#
# | TC ID | Description | Test Data (user_id, name, email) | Expected Result | Actual Result | Status |
# |---|---|---|---|---|---|
# | TC-USER-001 | Validate user record fields are present and valid | (1, Alice Johnson, alice.johnson@example.com) |
# ...

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
              1. Introduction
              This document outlines the user requirements for the development of a mobile banking application. The application aims to provide users with a secure, efficient, and user-friendly platform to manage their banking needs on the go.

              2. User Requirements
              2.1. User Authentication
              2.1.1. The application shall allow users to log in using a combination of a username and password.
              2.1.2. The application shall support biometric authentication (fingerprint and facial recognition) for devices that support these features.
              2.1.3. The application shall implement two-factor authentication (2FA) for an added layer of security.
              2.2. Account Management
              2.2.1. Users shall be able to view their account balances for all linked accounts.
              2.2.2. Users shall be able to view transaction history for each account, with filters for date range and transaction type.
              2.2.3. Users shall be able to transfer funds between their own accounts.
              2.2.4. Users shall be able to transfer funds to external accounts using account numbers or email addresses.
              2.3. Payments and Transfers
              2.3.1. The application shall allow users to pay bills directly from their accounts.
              2.3.2. The application shall support scheduled payments and transfers.
              2.3.3. Users shall be able to set up recurring payments and transfers.
              2.4. Notifications
              2.4.1. Users shall receive push notifications for successful logins, transactions, and account updates.
              2.4.2. Users shall have the option to customize notification settings for different types of alerts.
              2.5. Security
              2.5.1. The application shall use end-to-end encryption for all data transmissions.
              2.5.2. The application shall automatically log out users after a period of inactivity (configurable by the user).
              2.5.3. The application shall allow users to remotely log out from all devices.
              2.6. User Interface
              2.6.1. The application shall have a user-friendly interface that is easy to navigate.
              2.6.2. The application shall be accessible to users with disabilities, adhering to relevant accessibility standards.
              2.6.3. The application shall be available in multiple languages, with language settings configurable by the user.
              2.7. Customer Support
              2.7.1. The application shall provide users with access to customer support via chat, email, and phone.
              2.7.2. The application shall include a comprehensive FAQ section.

              Write the functional requirement and non-functional requirement.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ## Functional Requirements (What the app must do)
#
# ### 1. User Authentication
# - **FR-1:** The application shall allow users to log in using a **username and password**.
# - **FR-2:** The application shall support **biometric authentication** (fingerprint and facial recognition) on
# supported devices.
# - **FR-3:** The application shall implement **two-factor authentication (2FA)** during login and/or sensitive
# actions (e.g., new payee, large transfers).
#
# ### 2. Account Management
# - **FR-4:** The application shall allow users to **view account balances** for all linked accounts.
# - **FR-5:** The application shall allow users to **view transaction history** per account.
# - **FR-6:** The application shall provide **filters** for transaction history by **date range** and **transaction
# type**.
# - **FR-7:** The application shall allow users to **transfer funds between their own accounts**.
# ...

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            "In a quiet village, a young girl named Mia discovered a hidden key in her grandmother's attic. Curious, she followed a map etched on the key, leading her to an ancient oak tree in the forest. As she turned the key in a concealed lock, a door opened, revealing a magical world filled with talking animals and shimmering rivers. Mia befriended a wise fox who guided her through enchanting adventures. When she returned home, she knew the magic was real, for the key glowed warmly in her hand, a reminder of the wonders just beyond the ordinary."

            Format the text into 3 sectors.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ### Sector 1
# In a quiet village, a young girl named Mia discovered a hidden key in her grandmother's attic. Curious, she
# followed a map etched on the key, leading her to an ancient oak tree in the forest.
#
# ### Sector 2
# As she turned the key in a concealed lock, a door opened, revealing a magical world filled with talking animals and
# shimmering rivers. Mia befriended a wise fox who guided her through enchanting adventures.
#
# ### Sector 3
# When she returned home, she knew the magic was real, for the key glowed warmly in her hand, a reminder of the
# wonders just beyond the ordinary.

# %% [markdown]
# ## Chat

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": "Hi"
        },
        {
            "role" : "assistant",
            "content" : "Hello! How can I assist you today?"
        },
        {
            "role": "user",
            "content": "Could you count 1 to 5 ?"
        },
        {
            "role" : "assistant",
            "content" : "Sure! Here you go: 1 2 3 4 5 Is there anything else you need help with?"
        },
        {
            "role": "user",
            "content": "Change to Chinese "
        }

    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# 1 到 5：一、二、三、四、五

# %% [markdown]
# ## Technical term (Retrieve)

# %%
from openai import OpenAI # เรียกใช้งาน OpenAI Library
API_KEY="REDACTED_OPENAI_API_KEY" # ใช้งาน GPT-5 หรือ GPT ตัวอื่น ๆ
client = OpenAI(
    api_key = API_KEY,
)
base_model = "gpt-3.5-turbo"

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            ``` python
            def calculate_square_area (x, y) :
              return x * y
            ```
            Write unit test.
            Return only code.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ``` python
# def test_calculate_square_area():
#     assert calculate_square_area(5, 5) == 25
#     assert calculate_square_area(0, 10) == 0
#     assert calculate_square_area(3, 4) == 12
#     assert calculate_square_area(8, 2) == 16
# ```

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            ``` python
            def calculate_square_area (x, y) :
              return x * y
            ```
            Write boundary test.
            Return only code.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ``` python
# assert calculate_square_area(0, 5) == 0
# assert calculate_square_area(5, 0) == 0
# assert calculate_square_area(-5, 5) == 0
# assert calculate_square_area(5, -5) == 0
# ```
#
# ``` python
# assert calculate_square_area(5, 5) == 25
# ```

# %%
res = client.chat.completions.create(
    model=base_model,
    messages=[
        {
            "role": "user",
            "content": """
            ``` python
            def calculate_square_area (x, y) :
              return x * y
            ```
            Write equivalence partitioning test.
            Return only code.
            """
        },
    ],
    stream=False
)
print(res.choices[0].message.content)
# Out:
# ``` python
# import unittest
#
# def test_calculate_square_area(self):
#   test_cases = [
#     # Valid input
#     (1, 1, 1),
#     (2, 3, 6),
#     (10, 5, 50),
#
#     # Invalid input
#     (-1, 2, None),
#     (3, -4, None),
#     (-5, -5, None),
#     (0, 5, None),
#     (5, 0, None)
#   ]
#
#   for x, y, expected in test_cases:
#     result = calculate_square_area(x, y)
#     self.assertEqual(result, expected)
# ```

# %%
def calculate(x:int, y:int) :
  print x*y
